# %%
print("Hello world!")
# Out:
# Hello world!

# %%
import pandas as pd
df=pd.read_csv("C:/Users/benny/Downloads/Student_performance_data _.csv")

# %%
df.head()
# Out:
#    StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0       1001   17       1          0                  2        19.833723
# 1       1002   18       0          0                  1        15.408756
# 2       1003   15       0          2                  3         4.210570
# 3       1004   17       1          0                  3        10.028829
# 4       1005   17       1          0                  2         4.672495
#
#    Absences  Tutoring  ParentalSupport  Extracurricular  Sports  Music  \
# 0         7         1                2                0       0      1
# 1         0         0                1                0       0      0
# 2        26         0                2                0       0      0
# 3        14         0                3                1       0      0
# 4        17         1                3                0       0      0
#
#    Volunteering       GPA  GradeClass
# 0             0  2.929196         2.0
# ...

# %%
df.isna().sum()
# Out:
# StudentID            0
# Age                  0
# Gender               0
# Ethnicity            0
# ParentalEducation    0
# StudyTimeWeekly      0
# Absences             0
# Tutoring             0
# ParentalSupport      0
# Extracurricular      0
# Sports               0
# Music                0
# Volunteering         0
# GPA                  0
# GradeClass           0
# dtype: int64

# %%
df.describe()
# Out:
#          StudentID          Age       Gender    Ethnicity  ParentalEducation  \
# count  2392.000000  2392.000000  2392.000000  2392.000000        2392.000000
# mean   2196.500000    16.468645     0.510870     0.877508           1.746237
# std     690.655244     1.123798     0.499986     1.028476           1.000411
# min    1001.000000    15.000000     0.000000     0.000000           0.000000
# 25%    1598.750000    15.000000     0.000000     0.000000           1.000000
# 50%    2196.500000    16.000000     1.000000     0.000000           2.000000
# 75%    2794.250000    17.000000     1.000000     2.000000           2.000000
# max    3392.000000    18.000000     1.000000     3.000000           4.000000
#
#        StudyTimeWeekly     Absences     Tutoring  ParentalSupport  \
# count      2392.000000  2392.000000  2392.000000      2392.000000
# mean          9.771992    14.541388     0.301421         2.122074
# std           5.652774     8.467417     0.458971         1.122813
# ...

# %%
for x in df:
    print(df[x].value_counts())
# Out:
# StudentID
# 3392    1
# 1001    1
# 1002    1
# 1003    1
# 1004    1
#        ..
# 1013    1
# 1012    1
# 1011    1
# 1010    1
# 1009    1
# Name: count, Length: 2392, dtype: int64
# Age
# 15    630
# 16    593
# 17    587
# 18    582
# Name: count, dtype: int64
# Gender
# 1    1222
# 0    1170
# Name: count, dtype: int64
# Ethnicity
# 0    1207
# 1     493
# 2     470
# 3     222
# Name: count, dtype: int64
# ParentalEducation
# 2    934
# 1    728
# 3    367
# 0    243
# 4    120
# Name: count, dtype: int64
# StudyTimeWeekly
# 17.819907    1
# 19.833723    1
# 15.408756    1
# 4.210570     1
# 10.028829    1
#             ..
# 10.038712    1
# 7.598486     1
# 11.851364    1
# 18.444466    1
# 4.562008     1
# Name: count, Length: 2392, dtype: int64
# Absences
# 13    93
# 25    93
# 12    92
# 8     91
# 20    90
# 19    90
# 6     88
# 15    87
# 23    86
# 7     86
# 1     85
# 14    84
# 27    84
# 21    83
# 5     83
# 17    81
# 24    81
# 26    80
# 3     79
# 18    79
# ...

# %%
"""import seaborn as sns
import matplotlib.pyplot as plt
for x in df:
    plt.figure(figsize=(10, 10))
    sns.distplot(df[x], bins=50, kde=True, color='blue')
    plt.show()"""
# Out:
# "import seaborn as sns\nimport matplotlib.pyplot as plt\nfor x in df:\n    plt.figure(figsize=(10, 10))\n    sns.distplot(df[x], bins=50, kde=True, color='blue')\n    plt.show()"

# %%
df.dtypes
# Out:
# StudentID              int64
# Age                    int64
# Gender                 int64
# Ethnicity              int64
# ParentalEducation      int64
# StudyTimeWeekly      float64
# Absences               int64
# Tutoring               int64
# ParentalSupport        int64
# Extracurricular        int64
# Sports                 int64
# Music                  int64
# Volunteering           int64
# GPA                  float64
# GradeClass           float64
# dtype: object

# %%
df["GradeClass"].value_counts()
# Out:
# GradeClass
# 4.0    1211
# 3.0     414
# 2.0     391
# 1.0     269
# 0.0     107
# Name: count, dtype: int64

# %%
df["GradeClass"]=df["GradeClass"].astype(int)

# %%
df=df.drop("StudentID",axis=1)

# %%
df
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
def remove_outliers(data):
    cleaned_data = data.copy()
    numeric_columns = data.select_dtypes(include="number").columns
    
    for column in numeric_columns:
        q1 = data[column].quantile(0.25)
        q3 = data[column].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (iqr * 1.5)
        upper_bound = q3 + (iqr * 1.5)
        
        
        cleaned_data = cleaned_data[(cleaned_data[column] > lower_bound) & (cleaned_data[column] < upper_bound)]
    
    return cleaned_data

# %%
df=remove_outliers(df)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Ethnicity, ParentalEducation, StudyTimeWeekly, Absences, Tutoring, ParentalSupport, Extracurricular, Sports, Music, Volunteering, GPA, GradeClass]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Ethnicity, ParentalEducation, StudyTimeWeekly, Absences, Tutoring, ParentalSupport, Extracurricular, Sports, Music, Volunteering, GPA, GradeClass]
# Index: []

# %%
df1=pd.read_csv("C:/Users/benny/Downloads/Student_performance_data _.csv")

# %%
df1
# Out:
#       StudentID  Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  \
# 0          1001   17       1          0                  2        19.833723
# 1          1002   18       0          0                  1        15.408756
# 2          1003   15       0          2                  3         4.210570
# 3          1004   17       1          0                  3        10.028829
# 4          1005   17       1          0                  2         4.672495
# ...         ...  ...     ...        ...                ...              ...
# 2387       3388   18       1          0                  3        10.680555
# 2388       3389   17       0          0                  1         7.583217
# 2389       3390   16       1          0                  2         6.805500
# 2390       3391   16       1          1                  0        12.416653
# 2391       3392   16       1          0                  2        17.819907
#
# ...

# %%
df1=df1.drop("StudentID",axis=1)

# %%
df2=df1

# %%
df1
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
df3=remove_outliers(df1)

# %%
df3
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Ethnicity, ParentalEducation, StudyTimeWeekly, Absences, Tutoring, ParentalSupport, Extracurricular, Sports, Music, Volunteering, GPA, GradeClass]
# Index: []

# %%
df=df2

# %%
df
# Out:
#       Age  Gender  Ethnicity  ParentalEducation  StudyTimeWeekly  Absences  \
# 0      17       1          0                  2        19.833723         7
# 1      18       0          0                  1        15.408756         0
# 2      15       0          2                  3         4.210570        26
# 3      17       1          0                  3        10.028829        14
# 4      17       1          0                  2         4.672495        17
# ...   ...     ...        ...                ...              ...       ...
# 2387   18       1          0                  3        10.680555         2
# 2388   17       0          0                  1         7.583217         4
# 2389   16       1          0                  2         6.805500        20
# 2390   16       1          1                  0        12.416653        17
# 2391   16       1          0                  2        17.819907        13
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_val,x_test,y_train_val,y_test=train_test_split(df.drop("GradeClass",axis=1),df["GradeClass"],test_size=0.2,random_state=2024)

# %%
X_train,X_val,y_train,y_val=train_test_split(X_train_val,y_train_val,test_size=0.1/0.8,random_state=42)

# %%
len(X_train_val)
# Out:
# 1913

# %%
len(X_train)
# Out:
# 1673

# %%
len(X_val)
# Out:
# 240

# %%
len(x_test)
# Out:
# 479

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier,BaggingClassifier
from sklearn.ensemble import VotingClassifier,BaggingClassifier,VotingClassifier,StackingClassifier,ExtraTreesClassifier,GradientBoostingClassifier,HistGradientBoostingClassifier

# %%
models=[BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=4),n_estimators=50),RandomForestClassifier(n_estimators=50),AdaBoostClassifier(n_estimators=100,algorithm="SAMME",random_state=0),GradientBoostingClassifier(n_estimators=100,learning_rate=0.1,random_state=0),ExtraTreesClassifier(n_estimators=100,random_state=0),HistGradientBoostingClassifier()]

# %%
for x in models:
    print(x.fit(X_train,y_train))
    print(x.score(x_test,y_test))
# Out:
# BaggingClassifier(estimator=KNeighborsClassifier(n_neighbors=4),
#                   n_estimators=50)
# 0.7077244258872651
# RandomForestClassifier(n_estimators=50)
# 0.9081419624217119
# AdaBoostClassifier(algorithm='SAMME', n_estimators=100, random_state=0)
# 0.9269311064718163
# GradientBoostingClassifier(random_state=0)
# 0.918580375782881
# ExtraTreesClassifier(random_state=0)
# 0.8517745302713987
# HistGradientBoostingClassifier()
# 0.918580375782881

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier,ExtraTreeClassifier
from sklearn.semi_supervised import SelfTrainingClassifier
from sklearn.cluster import cluster_optics_dbscan,AgglomerativeClustering,cluster_optics_xi,k_means,BisectingKMeans,MiniBatchKMeans,KMeans

# %%
models1 = [
    MultinomialNB(),
    SVC(gamma='auto'),
    DecisionTreeClassifier(random_state=0),
    ExtraTreeClassifier(random_state=0),
    SelfTrainingClassifier(KNeighborsClassifier(n_neighbors=3))
]

# %%
for x in models1:
    print(x.fit(X_train,y_train))
    print(x.score(x_test,y_test))
# Out:
# MultinomialNB()
# 0.7139874739039666
# SVC(gamma='auto')
# 0.7432150313152401
# DecisionTreeClassifier(random_state=0)
# 0.8517745302713987
# ExtraTreeClassifier(random_state=0)
# 0.6951983298538622
# SelfTrainingClassifier(base_estimator=KNeighborsClassifier(n_neighbors=3))
# 0.6993736951983298
# d:\python\student_performance\myenv\Lib\site-packages\sklearn\semi_supervised\_self_training.py:227: UserWarning: y contains no unlabeled samples
#   warnings.warn("y contains no unlabeled samples", UserWarning)

# %%
model=AdaBoostClassifier(n_estimators=100,algorithm="SAMME",random_state=0)

# %%
model.fit(X_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME', n_estimators=100, random_state=0)

# %%
model.score(x_test,y_test)
# Out:
# 0.9269311064718163

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.57      0.71        21
#          1.0       0.93      0.89      0.91        61
#          2.0       0.95      0.93      0.94        81
#          3.0       0.90      0.91      0.90        76
#          4.0       0.93      0.97      0.95       240
#
#     accuracy                           0.93       479
#    macro avg       0.93      0.85      0.88       479
# weighted avg       0.93      0.93      0.92       479

# %%
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# <Axes: >

# %%
import pickle
with open("model.pkl","wb") as f:
    pickle.dump(model,f)

# %%
X_val.to_json("X_val.json",orient='records')

# %%
with open("model.pkl","rb") as f:
    model=pickle.load(f)

# %%
data=X_train.iloc[0].values

# %%
import numpy as np

# %%
print(np.stack(data))
# Out:
# [16.          1.          0.          2.         12.49590797  8.
#   0.          2.          1.          0.          0.          0.
#   2.39768258]

# %%
model.predict(np.stack([data]))
# Out:
# d:\python\student_performance\myenv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostClassifier was fitted with feature names
#   warnings.warn(
# array([3.])

# %%
X_train.iloc[0]
# Out:
# Age                  16.000000
# Gender                1.000000
# Ethnicity             0.000000
# ParentalEducation     2.000000
# StudyTimeWeekly      12.495908
# Absences              8.000000
# Tutoring              0.000000
# ParentalSupport       2.000000
# Extracurricular       1.000000
# Sports                0.000000
# Music                 0.000000
# Volunteering          0.000000
# GPA                   2.397683
# Name: 431, dtype: float64

# %%
y_test.iloc[431]
# Out:
# np.float64(2.0)

# %%
X_train.columns
# Out:
# Index(['Age', 'Gender', 'Ethnicity', 'ParentalEducation', 'StudyTimeWeekly',
#        'Absences', 'Tutoring', 'ParentalSupport', 'Extracurricular', 'Sports',
#        'Music', 'Volunteering', 'GPA'],
#       dtype='object')
